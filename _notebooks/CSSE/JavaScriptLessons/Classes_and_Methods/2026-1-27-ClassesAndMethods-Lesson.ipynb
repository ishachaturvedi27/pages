# %%
layout: post
courses: { csse: {week: 5} } 
categories: [CSSE JavaScript]
microblog: true
codemirror: true
title: Iterations
description: Basics of Classes and 
permalink: /js/iterations
author: Aarnav Jain and Dean

# %% [markdown]
# **Classes and Methods**
